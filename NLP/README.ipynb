# %% [markdown]
# #  Классификация токсичных комментариев для Викишоп
#
# ##  Описание проекта
# Интернет-магазин «Викишоп» запускает новый сервис, где пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. Для поддержания здоровой коммуникационной среды необходим инструмент автоматической модерации токсичных комментариев.
#
# **Задача**: Обучить модель классифицировать комментарии на позитивные и негативные с метрикой качества **F1 ≥ 0.75**.
#
# ##  Данные
# Файл: `toxic_comments.csv`
# - `text` - текст комментария (объект)
# - `toxic` - целевой признак (0 - нормальный, 1 - токсичный)
#
# **Характеристики данных**:
# - Объём: 159,292 комментариев
# - Качество: без пропусков, пустых строк и дубликатов
# - Дисбаланс классов: ~87.4% нормальных vs ~12.6% токсичных
#
# ##  Технологический стек
#
# **NLP и обработка текста:**
# - spacy
# - nltk
# - re
#
# **Машинное обучение:**
# - scikit-learn
#
# **Анализ данных:**
# - pandas
# - numpy
# - matplotlib
#
# **Утилиты:**
# - tqdm
# - warnings
# - gc
